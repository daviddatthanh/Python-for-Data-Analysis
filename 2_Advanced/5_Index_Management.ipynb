# %% [markdown]
# Deal with the index getting messed up when filtering thus reseting the index and setting the index inplace (destructive)

# %%
import pandas as pd
from datasets import load_dataset

import matplotlib.pyplot as plt

#loading data
df = load_dataset('lukebarousse/data_jobs')['train'].to_pandas()

#data clean up
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df.describe()
df.info()
df.iloc[0:2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
#There are 3 functions to troubleshoot the index
#df.index
#returns the component make up of the index start end and step
#df.index.name = 'Something'
#renaming the index column name
#df.index.dtype
#this is to see the data type of the index

# %% [markdown]
# ##3 Methods to cover
# -df.reset_index()
# -df.set_index()
# -df.sort_index()

# %%
#an example of reseting index is when you filter out data

df_usa = df[df['job_country'] =='United States']
df_usa.index.name = 'job_index'
df_usa.index
# Out:
# Index([     0,      3,      5,      6,      9,     11,     13,     17,     26,
#            27,
#        ...
#        785625, 785626, 785641, 785648, 785651, 785673, 785685, 785692, 785703,
#        785705],
#       dtype='int64', name='job_index', length=206292)

# %%
df_usa.reset_index(inplace = True)
df_usa.index
df_usa
#keep the old index as it can be used to merge data frame
# Out:
#         job_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
#df_usa.set_index('job_index', inplace = True)
#setting index to a column will remove the orignal column whether thats the original index or a pivot table. keep that in mind.

# %%
#df.sort_index() is not very useful as index already sorted, or in a pivot table, you can just use .sort_values(by = ('')) . 
#The course mentioned that this function is useful when the column does not have a name
